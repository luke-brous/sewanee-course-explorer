# %%
import pandas as pd

# %%
df = pd.read_csv('data/spring_26_courses.csv')
df.head()
# Out:
#                uid                                   title  num    crn  \
# 0  202620AFST16041             African-American Literature  395  16041
# 1  202620AFST16070  Tropical Forest Ecology and Management  212  16070
# 2  202620AFST15946     African-American History since 1865  232  15946
# 3  202620AFST15952       Black Power to Black Lives Matter  318  15952
# 4  202620AFST16136     Globalization and Culture in Africa  108  16136
#
#   section  hours             times          faculty location  limit  enrolled  \
# 0       A      4   TR 1330-1445,          B Threatt      TBA     20         8
# 1       A      4  MWF 1200-1250,           T Harris      TBA     26        26
# 2       A      4   TR 1330-1445,        A Donaldson      TBA     26        24
# 3       A      4    M 1400-1630,        A Donaldson      TBA     15        11
# 4       A      4  MWF 1200-1250,    E Asiedu-Acquah      TBA     26        26
#
#                               available  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uid           600 non-null    object
#  1   title         600 non-null    object
#  2   num           600 non-null    int64
#  3   crn           600 non-null    int64
#  4   section       600 non-null    object
#  5   hours         600 non-null    int64
#  6   times         600 non-null    object
#  7   faculty       600 non-null    object
#  8   location      600 non-null    object
#  9   limit         600 non-null    int64
#  10  enrolled      600 non-null    int64
#  11  available     600 non-null    object
#  12  info          542 non-null    object
#  13  description   560 non-null    object
#  14  subj          600 non-null    object
#  15  subject       600 non-null    object
#  16  subj_code     600 non-null    object
#  17  cat_term      600 non-null    int64
# ...

# %%
df
# Out:
#                  uid                                              title  num  \
# 0    202620AFST16041                        African-American Literature  395
# 1    202620AFST16070             Tropical Forest Ecology and Management  212
# 2    202620AFST15946                African-American History since 1865  232
# 3    202620AFST15952                  Black Power to Black Lives Matter  318
# 4    202620AFST16136                Globalization and Culture in Africa  108
# ..               ...                                                ...  ...
# 595  202620WMST16214                        Comparative Sexual Behavior  213
# 596  202620WMST16101         Introduction to the Bible I: Old Testament  143
# 597  202620WMST16102         Introduction to the Bible I: Old Testament  143
# 598  202620WMST16188                   Feminist Theory, Methods, Praxis  360
# 599  202620WMST16274  The Sexual and Racial Politics of Meat: Food J...  362
#
# ...

# %%
print(df.shape[0], df.shape[1])
# Out:
# 600 19

# %%
print(df.columns.get_loc('description'))
dirty_descriptions = df['description'].tolist()
# Out:
# 13

# %%
print(df.columns.tolist())
print(df.columns.get_loc('subj'))
print(df.columns[14])
# Out:
# ['uid', 'title', 'num', 'crn', 'section', 'hours', 'times', 'faculty', 'location', 'limit', 'enrolled', 'available', 'info', 'description', 'subj', 'subject', 'subj_code', 'cat_term', 'credit_hours']
# 14
# subj

# %%
# clean times to remove the last comma
print(df.columns.get_loc('times'))

df['times'] = df['times'].str.replace(',', '').str.strip()
df['times'][0:10]
# Out:
# 6
# 0     TR 1330-1445
# 1    MWF 1200-1250
# 2     TR 1330-1445
# 3      M 1400-1630
# 4    MWF 1200-1250
# 5     TR 1100-1215
# 6     TR 1100-1215
# 7      W 1400-1630
# 8      W 1400-1630
# 9     TR 1100-1215
# Name: times, dtype: object

# %%
df.head()
# Out:
#                uid                                   title  num    crn  \
# 0  202620AFST16041             African-American Literature  395  16041
# 1  202620AFST16070  Tropical Forest Ecology and Management  212  16070
# 2  202620AFST15946     African-American History since 1865  232  15946
# 3  202620AFST15952       Black Power to Black Lives Matter  318  15952
# 4  202620AFST16136     Globalization and Culture in Africa  108  16136
#
#   section  hours          times          faculty location  limit  enrolled  \
# 0       A      4   TR 1330-1445        B Threatt      TBA     20         8
# 1       A      4  MWF 1200-1250         T Harris      TBA     26        26
# 2       A      4   TR 1330-1445      A Donaldson      TBA     26        24
# 3       A      4    M 1400-1630      A Donaldson      TBA     15        11
# 4       A      4  MWF 1200-1250  E Asiedu-Acquah      TBA     26        26
#
#                               available  \
# 0                         Available: 12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uid           600 non-null    object
#  1   title         600 non-null    object
#  2   num           600 non-null    int64
#  3   crn           600 non-null    int64
#  4   section       600 non-null    object
#  5   hours         600 non-null    int64
#  6   times         600 non-null    object
#  7   faculty       600 non-null    object
#  8   location      600 non-null    object
#  9   limit         600 non-null    int64
#  10  enrolled      600 non-null    int64
#  11  available     600 non-null    object
#  12  info          542 non-null    object
#  13  description   560 non-null    object
#  14  subj          600 non-null    object
#  15  subject       600 non-null    object
#  16  subj_code     600 non-null    object
#  17  cat_term      600 non-null    int64
# ...
